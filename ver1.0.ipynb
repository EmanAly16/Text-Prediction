# %% [markdown]
# # CORPUS/DATA SET

# %%
import nltk
nltk.downloader.download("book","nltl_data")
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to nltl_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package brown to nltl_data...
# [nltk_data]    |   Unzipping corpora\brown.zip.
# [nltk_data]    | Downloading package chat80 to nltl_data...
# [nltk_data]    |   Unzipping corpora\chat80.zip.
# [nltk_data]    | Downloading package cmudict to nltl_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to nltl_data...
# [nltk_data]    |   Unzipping corpora\conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to nltl_data...
# [nltk_data]    |   Unzipping corpora\conll2002.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     nltl_data...
# [nltk_data]    |   Unzipping corpora\dependency_treebank.zip.
# [nltk_data]    | Downloading package genesis to nltl_data...
# ...

# %% [markdown]
# # TEXT NORMALIZATION

# %%
from nltk.corpus import stopwords
import string
import re
from nltk.book import*
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# # DATA CLEANING

# %%
stopwords_list=stopwords.words('english')
ftext=" ".join(text1)
LowerText=ftext.lower()
CleanText=re.findall(r"(\b[A-Za-z]+)\b",LowerText)
CleanText
# Out:
# ['moby',
#  'dick',
#  'by',
#  'herman',
#  'melville',
#  'etymology',
#  'supplied',
#  'by',
#  'a',
#  'late',
#  'consumptive',
#  'usher',
#  'to',
#  'a',
#  'grammar',
#  'school',
#  'the',
#  'pale',
#  'usher',
#  'threadbare',
#  'in',
#  'coat',
#  'heart',
#  'body',
#  'and',
#  'brain',
#  'i',
#  'see',
#  'him',
#  'now',
#  'he',
#  'was',
#  'ever',
#  'dusting',
#  'his',
#  'old',
#  'lexicons',
#  'and',
#  'grammars',
#  'with',
#  'a',
#  'queer',
#  'handkerchief',
#  'mockingly',
#  'embellished',
#  'with',
#  'all',
#  'the',
#  'gay',
#  'flags',
#  'of',
#  'all',
#  'the',
#  'known',
#  'nations',
#  'of',
#  'the',
#  'world',
#  'he',
#  'loved',
#  'to',
#  'dust',
#  'his',
#  'old',
#  'grammars',
#  'it',
#  'somehow',
#  'mildly',
#  'reminded',
#  'him',
#  'of',
#  'his',
#  'mortality',
#  'while',
#  'you',
#  'take',
#  'in',
#  'hand',
#  'to',
#  'school',
#  'others',
#  'and',
#  'to',
#  'teach',
#  'them',
#  'by',
#  'what',
# ...

# %% [markdown]
# # SPLITTING DATA TO TRAIN AND TEST DATA

# %%
import nltk
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(CleanText, train_size=0.2, test_size=0.8)

# %% [markdown]
# # BIGRAM ALGORITHM

# %%
def Bi_Grams(CleanText):
    BigramText=" ".join(CleanText)
    bigram=nltk.collocations.BigramCollocationFinder.from_words(BigramText.split())
    for bigram,freq in bigram.ngram_fd.items():
        print(bigram,freq)
train_bi_set=Bi_Grams(train_set)
# Out:
# ('man', 'trumpets') 1
# ('trumpets', 'afraid') 1
# ('afraid', 'zhiv') 1
# ('zhiv', 'a') 1
# ('a', 'carrying') 1
# ('carrying', 'teeth') 1
# ('teeth', 'some') 1
# ('some', 't') 1
# ('t', 'guy') 1
# ('guy', 'ran') 1
# ('ran', 'when') 1
# ('when', 'he') 1
# ('he', 'mile') 1
# ('mile', 'that') 1
# ('that', 'yes') 1
# ('yes', 'went') 1
# ('went', 're') 1
# ('re', 'girls') 1
# ('girls', 'should') 1
# ('should', 'swallow') 1
# ('swallow', 'word') 1
# ('word', 'narrator') 1
# ('narrator', 'hee') 1
# ('hee', 'nothing') 1
# ('nothing', 'sir') 1
# ('sir', 'tit') 1
# ('tit', 'a') 1
# ('a', 'i') 3
# ('i', 'no') 3
# ('no', 'dramatically') 1
# ('dramatically', 'ni') 1
# ('ni', 'the') 4
# ('the', 'listen') 1
# ('listen', 'french') 1
# ('french', 'see') 1
# ('see', 'out') 1
# ('out', 'thy') 1
# ('thy', 'dramatic') 1
# ('dramatic', 'but') 1
# ('but', 'what') 1
# ('what', 'lord') 1
# ('lord', 'my') 1
# ('my', 'practice') 1
# ('practice', 'got') 1
# ('got', 'a') 1
# ('a', 'too') 1
# ...

# %% [markdown]
# # COMPUTING PROBABILITES

# %%
def t2_given_t1(t2,t1,train_bag)
